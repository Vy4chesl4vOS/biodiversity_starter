# %% [markdown]
# # Importing libraries and reading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set_palette("Spectral")

# %%
observations = pd.read_csv('observations.csv')
species = pd.read_csv('species_info.csv')

# %% [markdown]
# ### Getting some information about an observations

# %%
observations.head(10)
# Out:
#                      scientific_name                            park_name  \
# 0                 Vicia benghalensis  Great Smoky Mountains National Park
# 1                     Neovison vison  Great Smoky Mountains National Park
# 2                  Prunus subcordata               Yosemite National Park
# 3               Abutilon theophrasti                  Bryce National Park
# 4           Githopsis specularioides  Great Smoky Mountains National Park
# 5  Elymus virginicus var. virginicus               Yosemite National Park
# 6                   Spizella pusilla            Yellowstone National Park
# 7                  Elymus multisetus  Great Smoky Mountains National Park
# 8             Lysimachia quadrifolia               Yosemite National Park
# 9         Diphyscium cumberlandianum            Yellowstone National Park
#
#    observations
# 0            68
# 1            77
# 2           138
# 3            84
# 4            85
# 5           112
# 6           228
# ...

# %%
observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23296 entries, 0 to 23295
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   scientific_name  23296 non-null  object
#  1   park_name        23296 non-null  object
#  2   observations     23296 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 546.1+ KB

# %%
observations.describe()
# Out:
#        observations
# count  23296.000000
# mean     142.287904
# std       69.890532
# min        9.000000
# 25%       86.000000
# 50%      124.000000
# 75%      195.000000
# max      321.000000

# %% [markdown]
# ### The same with a species

# %%
species.head(10)
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
# 5   Mammal         Odocoileus virginianus
# 6   Mammal                     Sus scrofa
# 7   Mammal                  Canis latrans
# 8   Mammal                    Canis lupus
# 9   Mammal                    Canis rufus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN
# ...

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5824 entries, 0 to 5823
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   category             5824 non-null   object
#  1   scientific_name      5824 non-null   object
#  2   common_names         5824 non-null   object
#  3   conservation_status  191 non-null    object
# dtypes: object(4)
# memory usage: 182.1+ KB

# %% [markdown]
# ## Merge these dataframes

# %%
data = pd.merge(observations , species)

# %%
data.head(10)
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
# 2  Vicia benghalensis            Yellowstone National Park           247
# 3  Vicia benghalensis                  Bryce National Park           104
# 4      Neovison vison  Great Smoky Mountains National Park            77
# 5      Neovison vison            Yellowstone National Park           218
# 6      Neovison vison                  Bryce National Park            91
# 7      Neovison vison               Yosemite National Park           200
# 8   Prunus subcordata               Yosemite National Park           138
# 9   Prunus subcordata            Yellowstone National Park           217
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25632 entries, 0 to 25631
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scientific_name      25632 non-null  object
#  1   park_name            25632 non-null  object
#  2   observations         25632 non-null  int64
#  3   category             25632 non-null  object
#  4   common_names         25632 non-null  object
#  5   conservation_status  880 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Drop dublicates according scientific_name and park_name

# %%
data.duplicated().sum()
# Out:
# 31

# %%
data.drop_duplicates(subset=['scientific_name', 'park_name'] ,inplace=True)

# %%
data.duplicate().sum()
# Out:
# 0

# %% [markdown]
# #### What's about unique values?

# %%
data.scientific_name.unique()
# Out:
# array(['Vicia benghalensis', 'Neovison vison', 'Prunus subcordata', ...,
#        'Ranunculus hebecarpus', 'Gulo gulo', 'Dichanthelium depauperatum'],
#       dtype=object)

# %%
len(data.scientific_name.unique())
# Out:
# 5541

# %%
data.park_name.unique()
# Out:
# array(['Great Smoky Mountains National Park', 'Yosemite National Park',
#        'Yellowstone National Park', 'Bryce National Park'], dtype=object)

# %%
len(data.park_name.unique())
# Out:
# 4

# %%
data.category.unique()
# Out:
# array(['Vascular Plant', 'Mammal', 'Bird', 'Nonvascular Plant',
#        'Amphibian', 'Reptile', 'Fish'], dtype=object)

# %%
len(data.category.unique())
# Out:
# 7

# %%
data.common_names.unique()
# Out:
# array(['Purple Vetch, Reddish Tufted Vetch', 'American Mink',
#        'Klamath Plum', ..., 'Delicate Buttercup, Downy-Fruit Buttercup',
#        'Wolverine', 'Green Panic-Grass, Panic Grass'], dtype=object)

# %%
len(data.common_names.unique())
# Out:
# 5229

# %% [markdown]
# #### Check NaN values

# %%
data.conservation_status.isna().sum()
# Out:
# 21452

# %%
data['conservation_status'].fillna('No concerned' ,inplace=True)

# %%
data.conservation_status.isna().sum()
# Out:
# 0

# %%
data.head(2)
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch        No concerned
# 1  Vascular Plant  Purple Vetch, Reddish Tufted Vetch        No concerned

# %% [markdown]
# # Analytics

# %%
park_count = data.groupby('park_name')['observations'].mean()
print(park_count)

category_count = data.category.value_counts()
# Out:
# park_name
# Bryce National Park                     98.926728
# Great Smoky Mountains National Park     74.210431
# Yellowstone National Park              247.903988
# Yosemite National Park                 148.218192
# Name: observations, dtype: float64

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.barplot(x=park_count.index, y=park_count.values)
plt.xticks(rotation=90)
plt.title('Mean observations in the parks')

plt.subplot(1, 2, 2)
sns.barplot(x=category_count.index, y=category_count.values)
plt.xticks(rotation=90)
plt.title('Category counts')

plt.show()
plt.clf()

# %% [markdown]
# Most observations in Yellowstone National Park and most popular category is Vascular Plant

# %%
conservation_count = data.conservation_status.value_counts()
conservation_count
# Out:
# No concerned          21452
# Species of Concern      604
# Endangered               60
# Threatened               36
# In Recovery              12
# Name: conservation_status, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(conservation_count.values[:-2],autopct='%.1f%%', radius=1, pctdistance=1.3)
plt.legend(conservation_count.index)
plt.show()
plt.clf()

# %% [markdown]
# ### Check relationships between category, names and conservations

# %%
for status in conservation_count.index:
    status_data = data[data.conservation_status == status]['category'].value_counts()
    plt.figure(figsize=(10, 5))
    sns.barplot(x=status_data.index, y=status_data.values)
    plt.title(f'{status} count')
    try:
        print(status_data.values[0] / np.sum(status_data.values), '%')
        print(status_data.values[1] / np.sum(status_data.values), '%')
        print(status_data.values[2] / np.sum(status_data.values), '%')
    except:
        print('')
    plt.show()
    plt.clf()
# Out:
# 0.7861271676300579 %
# 0.07700913667723289 %
# 0.061159798620175274 %
# 0.4503311258278146 %
# 0.2847682119205298 %
# 0.1456953642384106 %
# 0.4 %
# 0.26666666666666666 %
# 0.2 %
# 0.3333333333333333 %
# 0.2222222222222222 %
# 0.2222222222222222 %
# 1.0 %

# %% [markdown]
# The same with park name

# %%
for status in conservation_count.index:
    status_data = data[data.conservation_status == status]['park_name'].value_counts()
    plt.figure(figsize=(15, 5))
    sns.barplot(x=status_data.index, y=status_data.values)
    plt.title(f'{status} count')
    plt.show()
    plt.clf()

# %% [markdown]
# Equal

# %% [markdown]
#  # Conclusion

# %% [markdown]
# ### 1. All parks contain rare species with equal part.
# ### 2. We have a tend to Species of Concern.
# ### 3. Species which have a tend to be in dangerous: Bird(but recovering), Mammal, Fish, Vascular Plant
